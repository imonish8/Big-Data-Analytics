# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x0 = np.array([21,32,45,95])
y0 = np.array([44,66,78,99])
plt.figure(figsize=(9,6))
plt.subplot(2,3,1)

x1 = np.array([21,32,45,95])
y1 = np.array([44,66,78,99])
plt.plot(x1,y1)
plt.subplot(2,3,2)

x2 = np.array([21,32,45,95])
y2 = np.array([44,66,78,99])
plt.plot(x2,y2)
plt.subplot(2,3,3)

x3 = np.array([21,32,45,95])
y3 = np.array([44,66,78,99])
plt.plot(x3,y3)
plt.subplot(2,3,4)

x4 = np.array([21,32,45,95])
y4 = np.array([44,66,78,99])
plt.plot(x4,y4)
plt.subplot(2,3,5)

x5 = np.array([21,32,45,95])
y5 = np.array([44,66,78,99])
plt.plot(x5,y5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.subplot(2,3,6)

plt.tight_layout()

# %%
#scattered
x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("boss")
plt.legend()

# %%
x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]
plt.figure(figsize=(9,9))
plt.subplot(3,3,1)
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("boss")
plt.legend()

x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]
#plt.figure(figsize=(9,6))
plt.subplot(3,3,2)
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("Toss")
plt.legend()

x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]
#plt.figure(figsize=(9,6))
plt.subplot(3,3,3)
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("Loss")
plt.legend()

x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]
#plt.figure(figsize=(9,6))
plt.subplot(3,3,4)
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("Moss")
plt.legend()

x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]

plt.subplot(3,3,5)
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("Foss")
plt.legend()

x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]

plt.subplot(3,3,6)
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("Koss")
plt.legend()

x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]

plt.subplot(3,3,7)
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("Coss")
plt.legend()

x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]

plt.subplot(3,3,8)
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("toosed")
plt.legend()

x =[13,2,22]
y =[34,42,11]
x2 = [33,21,42]
y2 = [44,55,66]

plt.subplot(3,3,9)
plt.plot(x,y,'r',label='lineone',linewidth=5)
plt.plot(x2,y2,'g',label='linetwo',linewidth=5)
plt.xlabel("axis x")
plt.ylabel("axis y")
plt.title("Matplot example")
plt.legend()

plt.tight_layout()

# %%
#ax = plt.subplot()

t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)

line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.figure(figsize=(20,15))
plt.ylim(-2,2)
plt.subplot(5,5,1)


#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,2)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,3)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,4)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,5)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,6)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,7)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,8)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,9)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,10)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,11)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,12)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,13)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,14)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,15)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,16)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,17)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,18)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,19)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,20)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,21)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,22)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,23)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,24)

#ax = plt.subplot()
t = np.arange(00.0,5.0,0.01)
s = np.cos(2*np.pi*t)
line, =plt.plot(t,s,lw=2)
plt.annotate('local max', xy = (2,1), xytext=(3,1.5),arrowprops=dict(facecolor='blue', shrink=0.05),)
plt.ylim(-2,2)
plt.subplot(5,5,25)

plt.tight_layout()

# %%
x = [16,17,18,19,100,22,56,78]
y =[8,9,10,11,12,13,14,16]
c = ['red','green','yellow','blue', 'hotpink', 'brown','black', 'lightblue']
plt.scatter(x,y,color=c)

# %%
x = [16,17,18,19,100,22,56,78]
#x = [16.4,17.5,18.6,19.7,100.7,22.22,56.11,78.21]
y =[8,9,10,11,12,13,14,16]
#y =[8.1,9.2,10.3,11.4,12.5,13.6,14.7,16.8]
#c = ['red','green','yellow','blue', 'hotpink', 'brown','black', 'lightblue']
size =[10,20,30,40,50,60,70,80]
color = [1.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80]
plt.scatter(x,y,c=color,s=size,cmap='twilight',alpha=0.5)
plt.colorbar()

# %%
import numpy as np
x = np.random.randint(100,size=(100))
y = np.random.randint(100, size=(100))
color = np.random.randint(100, size =(100))
size = 10*np.random.randint(100, size =(100))
plt.scatter(x,y,c=color,s=size, alpha=0.5,cmap='nipy_spectral')
plt.colorbar()

# %%
x = [2,4,6]
y = [8,16,32]
x1 = [4,8,12]
y1 = [6,12,18]
plt.bar(x,y,color='y',align='edge')
plt.bar(x1,y1,color='b',align='edge')
# Out:
# <BarContainer object of 3 artists>

# %%
data = [54,34,22,33]
fruits = ['apple', 'samsung', 'sony','nokia']
explode = [0.60,0.70,0.80,0.90]
plt.pie(data, labels=fruits,explode=explode, shadow=True)
#plt.pie(x,y)
# Out:
# ([<matplotlib.patches.Wedge at 0x125e087a0>,
# ...
#  [Text(0.6376006532287805, 1.5759014585316662, 'apple'),
#   Text(-1.7995656350724785, 0.0395414348018213, 'samsung'),
#   Text(-0.673749526476557, -1.7765307696667163, 'sony'),
#   Text(1.4970207042227606, -1.326246210599069, 'nokia')])

# %%
data = [54,34,22,33]
fruits = ['apple', 'samsung', 'sony','nokia']
explode = [0.60,0.70,0.80,0.90]
plt.pie(data, labels=fruits,explode=explode, shadow=True)
#plt.pie(x,y)
# Out:
# ([<matplotlib.patches.Wedge at 0x125ecbc80>,
# ...
#  [Text(0.6376006532287805, 1.5759014585316662, 'apple'),
#   Text(-1.7995656350724785, 0.0395414348018213, 'samsung'),
#   Text(-0.673749526476557, -1.7765307696667163, 'sony'),
#   Text(1.4970207042227606, -1.326246210599069, 'nokia')])

# %%
NEIGHBOURS = ['INDIA','AUSTRALIA','SRILANKA','PAKISTAN','AFGANISTAN','CHINA','BANGLA']
FIGHTS = [1,2,3,4,5,6,7]
IND= [X for X, _ in enumerate(NEIGHBOURS)]
plt.bar(IND, FIGHTS, width=0.5, label = 'Most Fights', color = 'gold', bottom=FIGHTS)
plt.ylabel("y label")
plt.xlabel("x label")
# Out:
# Text(0.5, 0, 'x label')
