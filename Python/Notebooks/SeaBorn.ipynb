# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import ssl 
#from certifi import urllib.request 
penguins = sns.load_dataset ("penguins")
#penguins = pd.read_csv("/Users/imonish8/Downloads/penguins.csv")
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species",
ax=axs[0])
sns.histplot(data=penguins, x="species", hue="species", shrink=.8, alpha=.8, legend=False, ax=axs[1])
f.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
(
    sns.barplot(
    data=tips, x="day", y="tip",
    estimator="mean", errorbar=None,
)
    .set(title="Daily Tips ($)")
)

plt.show()

# %%
#using matplotlib
import matplotlib.pyplot as plt
import pandas as pd
tips = pd.read_csv("/Users/imonish8/Downloads/tips.csv")
average_daily_tip = (
tips
.groupby("day")["tip"]
 .mean()
)
days = ["Thur", "Fri", "Sat", "Sun"]
daily_averages = [
average_daily_tip["Thur"],
average_daily_tip["Fri"],
average_daily_tip["Sat"],
average_daily_tip["Sun"],
]
fig, ax = plt.subplots()
plt.bar(x=days, height=daily_averages)
ax.set_xlabel("day")
ax.set_ylabel("tip")
ax.set_title("Daily Tips ($)")
plt.show()

# %%
import pandas as pd
cross= pd.read_csv("/Users/imonish8/Downloads/nyc-east-river-bicycle-counts.csv")
(
    sns.scatterplot(data=cross, x ='High Temp (°F)', y ='Low Temp (°F)')
    .set(title="Minimum and MAXIMUM Temperature", xlabel="Minimum Temperature", ylabel = "Max Temperature")
)
plt.show()

# %%
#Sleep_Hours
#Family_Income
#Distance_from_Home
#Exam_Score
import pandas as pd
student= pd.read_csv("/Users/imonish8/Downloads/StudentPerformanceFactors.csv")

figure, ax = plt.subplots()
    #sns.scatterplot(data=student, x ='Sleep_Hours', y ='Exam_Score')
sns.kdeplot(data=student, x ='Exam_Score', y ='Physical_Activity', color="blue", ax=ax)
sns.rugplot(data=student, x ='Exam_Score', y ='Physical_Activity', color="black", ax=ax) 
    #.set(title="STUDENT", xlabel="SLEEP HRS", ylabel = "EXAM SCORE")
ax.set(title="STUDENT", xlabel="EXAM SCORE", ylabel = "Physical Activity")
plt.show()

"""
# y ='Family_Income'

#sns.scatterplot(data=student, x ='Exam_Score', y ='Family_Income')
sns.kdeplot(data=student, x ='Exam_Score', y ='Family_Income', color="black", ax=ax)
sns.rugplot(data=student, x ='Exam_Score',color ="blue", ax = ax)    
ax.set(title="STUDENT", xlabel="EXAM SCORE", ylabel = "FAMILY INCOME")
plt.show()
"""
# Out:
# '\n# y =\'Family_Income\'\n\n#sns.scatterplot(data=student, x =\'Exam_Score\', y =\'Family_Income\')\nsns.kdeplot(data=student, x =\'Exam_Score\', y =\'Family_Income\', color="black", ax=ax)\nsns.rugplot(data=student, x =\'Exam_Score\',color ="blue", ax = ax)    \nax.set(title="STUDENT", xlabel="EXAM SCORE", ylabel = "FAMILY INCOME")\nplt.show()\n'

# %%
#Population (2001 Census)
#Area (in Sq.km)
#Name of the ULB with Grade

# %%
sns.lineplot(data=student, x ='Sleep_Hours' ,y ='Physical_Activity')
plt.figure(figsize=(4,4))
plt.subplot(2,2,1)
sns.lineplot(data=student, x ='Exam_Score' ,y ='Physical_Activity')
plt.subplot(2,2,2)
sns.lineplot(data=student, x ='Exam_Score' ,y ='Physical_Activity')
plt.subplot(2,2,3)
sns.lineplot(data=student, x ='Exam_Score' ,y ='Physical_Activity')
plt.subplot(2,2,4)
plt.tight_layout()

"""
size =[10,20,30,40,50,60,70,80]
color = [1.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80]
plt.scatter(x ='Exam_Score' ,y ='Physical_Activity',c=color,s=size, alpha=0.5,cmap='nipy_spectral')
plt.colorbar()
"""
# Out:
# "\nsize =[10,20,30,40,50,60,70,80]\ncolor = [1.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80]\nplt.scatter(x ='Exam_Score' ,y ='Physical_Activity',c=color,s=size, alpha=0.5,cmap='nipy_spectral')\nplt.colorbar()\n"
