# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 7.9 MB/s eta 0:00:00 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = [1,2,3,4]
df = pd.Series(data, index = ['a', 'b','c','d'])
df
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data = {"Name" : ['Parul', 'Olive', 'Kevin', 'More'], 'Age' : [23,44,55,22]}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age
# 0  Parul   23
# 1  Olive   44
# 2  Kevin   55
# 3   More   22

# %%
data = {'English_marks' : [89,22,90,99,90], "Physics_Marks" : [80,83,85,86,90]}
df = pd.Series(data)
print(df)
# Out:
# English_marks    [89, 22, 90, 99, 90]
# Physics_Marks    [80, 83, 85, 86, 90]
# dtype: object

# %%
df = pd.DataFrame(data)
print(df)
df
# Out:
#    English_marks  Physics_Marks
# 0             89             80
# 1             22             83
# 2             90             85
# 3             99             86
# 4             90             90
#    English_marks  Physics_Marks
# 0             89             80
# 1             22             83
# 2             90             85
# 3             99             86
# 4             90             90

# %%
data = [['Alex', 30], ['Pandya', 33],['Laxmi', 33]]
df =pd.DataFrame(data)
df
# Out:
#         0   1
# 0    Alex  30
# 1  Pandya  33
# 2   Laxmi  33

# %%
import numpy as np
Sports = np.array(['Cricket', 'Football', 'Hockey', 'Tennis', 'Swimming'])
df = pd.DataFrame(Sports)
df
df[0:2]
# Out:
#           0
# 0   Cricket
# 1  Football

# %%
data = {"States" : ["Tamilnadu", "Karnataka", "Kerala", "Telangana", "Madhyapradesh", "Maharashtra"],
        "Capitol" : ["Chennai", "Banglore", "Th", "Hyderbad", "Bhopal", "Mumbai"],
        "Population" : [200,300,200,200,200, 400]}
df = pd.DataFrame(data, index=['TN','KA','KE', 'TE','MA','MH'])
print('index',df.index)
print(f'column : {df.columns}')
print(f'values : {df.values}')
# Out:
# index Index(['TN', 'KA', 'KE', 'TE', 'MA', 'MH'], dtype='object')
# column : Index(['States', 'Capitol', 'Population'], dtype='object')
# values : [['Tamilnadu' 'Chennai' 200]
#  ['Karnataka' 'Banglore' 300]
#  ['Kerala' 'Th' 200]
#  ['Telangana' 'Hyderbad' 200]
#  ['Madhyapradesh' 'Bhopal' 200]
#  ['Maharashtra' 'Mumbai' 400]]

# %%
data = np.arange(0,100,2)
df = pd.DataFrame(data, columns=['data'])
print(sum(df['data']))
# Out:
# 2450

# %%
print(min(df['data']))
# Out:
# 0

# %%
print(max(df['data']))
# Out:
# 98

# %%
print(df.to_string())
# Out:
#     data
# 0      0
# 1      2
# 2      4
# 3      6
# 4      8
# 5     10
# 6     12
# 7     14
# 8     16
# 9     18
# 10    20
# 11    22
# 12    24
# 13    26
# 14    28
# 15    30
# 16    32
# 17    34
# 18    36
# 19    38
# 20    40
# 21    42
# 22    44
# 23    46
# 24    48
# 25    50
# 26    52
# 27    54
# 28    56
# 29    58
# 30    60
# 31    62
# 32    64
# 33    66
# 34    68
# 35    70
# 36    72
# 37    74
# 38    76
# 39    78
# 40    80
# 41    82
# 42    84
# 43    86
# 44    88
# 45    90
# 46    92
# 47    94
# 48    96
# 49    98

# %%
print(df.head(10))
# Out:
#    data
# 0     0
# 1     2
# 2     4
# 3     6
# 4     8
# 5    10
# 6    12
# 7    14
# 8    16
# 9    18

# %%
print(df.tail(10))
# Out:
#     data
# 40    80
# 41    82
# 42    84
# 43    86
# 44    88
# 45    90
# 46    92
# 47    94
# 48    96
# 49    98

# %%
data =pd.read_csv('/Users/imonish8/Downloads/employees.csv')
df = pd.DataFrame(data)
df
# Out:
#             candidateName                            companyName  \
# 0         Ruchismita Dash                                Amdocs
# 1             MANISHA DAS  APOLLO HOSPITALS ENTERPRISES LIMITED
# 2        C J GEETHA PRIYA                   propertyoneshop.com
# 3                SRIKANTH                         Axis Bank Ltd
# 4        Madduri Srinivas                                   CTS
# ...                   ...                                    ...
# 28842       Nadeem Haider       SOTC KUONI TRAVEL INDIA PVT LTD
# 28843  Debabrata Karmakar                   Ibm Global Services
# 28844         Chirag Jain   Computer Sciences Corp Ltd  ( csc )
# 28845      Kunal Sachdeva                  Religare Enterprises
# 28846      Anuradha Sethi                               Infosys
#
#                        designation          experienceMas  \
# 0               Software Developer   2 Year(s) 1 Month(s)
# 1      SENIOR EXECUTIVE-OPERATIONS   5 Year(s) 9 Month(s)
# ...

# %%
df.isnull().any()
# Out:
# candidateName          True
# companyName            True
# designation            True
# experienceMas         False
# locationCurrentMas    False
# qualificationMas       True
# qualificationMas2      True
# salary                False
# Category              False
# dtype: bool

# %%
df.loc[:,["designation", "experienceMas", "salary"]].head(20)
# Out:
#                                           designation           experienceMas  \
# 0                                  Software Developer    2 Year(s) 1 Month(s)
# 1                         SENIOR EXECUTIVE-OPERATIONS    5 Year(s) 9 Month(s)
# 2                                System Administrator    4 Year(s) 4 Month(s)
# 3                                                 NaN   7 Year(s) 11 Month(s)
# 4                                  Associate Projects    6 Year(s) 8 Month(s)
# 5                                         Sr. Manager   20 Year(s) 2 Month(s)
# 6               Assistant Manager NonVoice Operations   11 Year(s) 4 Month(s)
# 7                                             Manager             12 Year(s)
# 8                              Zonal Business Manager   13 Year(s) 6 Month(s)
# 9                             Test Lead/Senior Tester   9 Year(s) 10 Month(s)
# 10                                                NaN   13 Year(s) 7 Month(s)
# ...

# %%
data = [["Alex",20],['Pandya', 22],['Laxmi', 22],['mani',22]]
df = pd.DataFrame(data, columns=['Name', 'Age'])
df.to_csv("/Users/imonish8/Downloads/users.csv",index=False)

# %%
df.sample(2)
# Out:
#      Name  Age
# 3    mani   22
# 1  Pandya   22

# %%
df.sample(2)
# Out:
#      Name  Age
# 1  Pandya   22
# 3    mani   22

# %%
#df = pd.read_csv('/Users/imonish8/Downloads/users.csv')
df.sample(2)
# Out:
#      Name  Age
# 2   Laxmi   22
# 1  Pandya   22

# %%
df = pd.read_csv('/Users/imonish8/Downloads/employees.csv')
df.iloc[0:50,-4:-1]
# Out:
#                     qualificationMas                 qualificationMas2  \
# 0           BE/ B.Tech (Engineering)                               NaN
# 1                          MBA/ PGDM               B.Pharm. (Pharmacy)
# 2                  B.Com. (Commerce)                               NaN
# 3                                NaN                         MBA/ PGDM
# 4                  B.Com. (Commerce)                        MCA/ PGDCA
# 5                                NaN                 Ph.D. (Doctorate)
# 6                          MBA/ PGDM                 B.Com. (Commerce)
# 7                                NaN                         MBA/ PGDM
# 8                    B.Sc. (Science)                               NaN
# 9           BE/ B.Tech (Engineering)                               NaN
# 10                               NaN                               NaN
# 11                 B.Com. (Commerce)                         MBA/ PGDM
# ...

# %%
df.to_csv("/Users/imonish8/Downloads/users.csv",index=False)
data = [["Alex",20,30000],['Pandya', 22,45000],['Laxmi', 22],['mani',22,'NaN']]

df = pd.DataFrame(data, columns=['Name', 'Age','Salary'])
df = pd.read_csv("/Users/imonish8/Downloads/users.csv")
#df.mean(df['Salary'])
#df.isnull().any()


df.to_csv("/Users/imonish8/Downloads/users.csv",index=False)
meanSalary = df['Salary'].mean()
#df['Salary'].fillna(meanSalary)
df['Salary']= df['Salary'].fillna(meanSalary)
df.to_csv("/Users/imonish8/Downloads/users.csv",index=False)
df = pd.read_csv("/Users/imonish8/Downloads/users.csv")
print(df)
#df = pd.read_csv("/Users/imonish8/Downloads/users.csv")
#print(df)
#print(df)
#print(meanSalary)
# Out:
#      Name  Age   Salary
# 0    Alex   20  30000.0
# 1  Pandya   22  45000.0
# 2   Laxmi   22  37500.0
# 3    mani   22  37500.0

# %%
df = pd.read_csv("/Users/imonish8/Downloads/users.csv")
print("Mean")
print(df)
meanSal = df['Salary'].mean()
df['Salary'] = df['Salary'].fillna(meanSal)
print("AFTER")
print(df)
# Out:
# Mean
#      Name  Age   Salary
# 0    Alex   20  30000.0
# 1  Pandya   22  45000.0
# 2   Laxmi   22      NaN
# 3    mani   22      NaN
# AFTER
#      Name  Age   Salary
# 0    Alex   20  30000.0
# 1  Pandya   22  45000.0
# 2   Laxmi   22  37500.0
# 3    mani   22  37500.0

# %%
df = pd.read_csv("/Users/imonish8/Downloads/users.csv")
print("STD")
print(df)
stdSal = df['Salary'].std()
df['Salary'] = df['Salary'].fillna(stdSal)
print("AFTER")
print(df)
# Out:
# STD
#      Name  Age   Salary
# 0    Alex   20  30000.0
# 1  Pandya   22  45000.0
# 2   Laxmi   22      NaN
# 3    mani   22      NaN
# AFTER
#      Name  Age        Salary
# 0    Alex   20  30000.000000
# 1  Pandya   22  45000.000000
# 2   Laxmi   22  10606.601718
# 3    mani   22  10606.601718

# %%
df = pd.read_csv("/Users/imonish8/Downloads/users.csv")
print("Mean")
print(df)
medianSal = df['Salary'].median()
df['Salary'] = df['Salary'].fillna(medianSal, limit=1)
print("AFTER")
print(df)
# Out:
# Mean
#      Name  Age   Salary
# 0    Alex   20  30000.0
# 1  Pandya   22  45000.0
# 2   Laxmi   22  37500.0
# 3    mani   22  37500.0
# AFTER
#      Name  Age   Salary
# 0    Alex   20  30000.0
# 1  Pandya   22  45000.0
# 2   Laxmi   22  37500.0
# 3    mani   22  37500.0

# %%
print("at 3 row")
df.at[3, 'Name'] = "Mani"
df.at[2, 'Salary'] = 300000000
print(df)
print("Updated Name mani -> Mani")
df.at[3, 'Name']
df.to_csv("/Users/imonish8/Downloads/users.csv",index=False)
df = pd.read_csv("/Users/imonish8/Downloads/users.csv")
print(df)
# Out:
# at 3 row
#      Name  Age       Salary
# 0    Alex   20      30000.0
# 1  Pandya   22      45000.0
# 2   Laxmi   22  300000000.0
# 3    Mani   22      37500.0
# Updated Name mani -> Mani
#      Name  Age       Salary
# 0    Alex   20      30000.0
# 1  Pandya   22      45000.0
# 2   Laxmi   22  300000000.0
# 3    Mani   22      37500.0

# %%
# ROW, COL
print("BEFORE")
print(df.iat[0,2])
print("AFTER")
df. iat[0,2]=4500000
df.to_csv("/Users/imonish8/Downloads/users.csv")
print(df. iat[0,2])

print(df)
df
# Out:
# BEFORE
# 4500000.0
# AFTER
# 4500000.0
#      Name  Age       Salary
# 0    Alex   20    4500000.0
# 1  Pandya   22      45000.0
# 2   Laxmi   22  300000000.0
# 3    Mani   22      37500.0
#      Name  Age       Salary
# 0    Alex   20    4500000.0
# 1  Pandya   22      45000.0
# 2   Laxmi   22  300000000.0
# 3    Mani   22      37500.0

# %%
df = pd.read_csv("/Users/imonish8/Downloads/users.csv")
df
# Out:
#    Unnamed: 0    Name  Age       Salary
# 0           0    Alex   20    4500000.0
# 1           1  Pandya   22      45000.0
# 2           2   Laxmi   22  300000000.0
# 3           3    Mani   22      37500.0

# %%
df['Salary'] > 50000
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# Name: Salary, dtype: bool

# %%
df.loc[lambda df : df['Salary'] == 45000]
# Out:
#    Unnamed: 0    Name  Age   Salary
# 1           1  Pandya   22  45000.0

# %%
#df = pd.DataFrame(data)
#data.append(["Name",["Wshwin","Shreya"],"Age" :[33,4444], "Salary" : [2000,333333]])

#data = {"Name" : {'Parul', 'Olive', 'Kevin', 'More'}, 'Age' : [23,44,55,22,6]}
#df = pd.DataFrame(data)
#data.append(["Name":["Wshwin","Shreya"],"Age" :[33,4444], "Salary" : [2000,333333]])

#data = {  "Name": ['Parul', 'Olive', 'Kevin', 'More', 'Sophia'],  "Age": [23, 44, 55, 22, 63]}
#df = pd.DataFrame(data)
#data.append(["Name":["Wshwin","Shreya"],"Age" :[33,4444], "Salary" : [2000,333333]])

print("printing appendined")
#print(df)
# Out:
# printing appendined

# %%
print(data)
data.append(["Hello", 33,34343])
# Out:
# {'Name': ['Parul', 'Olive', 'Kevin', 'More', 'Sophia'], 'Age': [23, 44, 55, 22, 63]}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[232], line 2
#       1 print(data)
# ----> 2 data.append(["Hello", 33,34343])
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
data.append([["HelloTesting", 30,222222]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[233], line 1
# ----> 1 data.append([["HelloTesting", 30,222222]])
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
data1 = ["world",220,202]
data1.append(["Hello", 30, 2000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 data1.append(["Hello", 30, 2000])
#
# NameError: name 'data1' is not defined

# %%
list1 = [23,33,333]
df = pd.DataFrame(list1)
list1.append(22)
df.to_csv("/Users/imonish8/Downloads/users1.csv",index=False)
list1.append(22)
df = pd.DataFrame(list1)
print(list1)
print(df)
# Out:
# [23, 33, 333, 22, 22]
#      0
# 0   23
# 1   33
# 2  333
# 3   22
# 4   22
