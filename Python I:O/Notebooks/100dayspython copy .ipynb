# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# - Algorithm efficiency is defined by Big O.
# - Time taken by the code is measured by number of operation the code is performing not the time taken for the code to run, this is because the running time for same code could vary on different machine but the number of operation. This Time Complexity.
# - Space taken by the code while running to assign variable and etc. is measured by space complexity.
# - Best case scenario, Average case scenario, Worst case scenario.
# - We focus on worst case scenario, it gives the efficiency of the code as big O Notation.
# - Technically there is no best case and Average case, we always calculate worst case.
# - O(1) - constant time complexity - eg simple code of addition or multiplication or subtraction with no loop, plain addition or subtraction.
# - O(N) - Linear Time complexity - eg, simple code of Loop through from 1 to n times. That is addition of 1 to 100 looping through 100 linear times.
# - O(LogN) - Logarithmic Time complexity which is finding an element in sorted array.
# - O(N^2) - Quadratic Time Complexity which often refers to Nested Loops. But may vary/
# - O(2^N) - exponential Time Complexity which as example the Combinational Lock. Where the Power represents the number of dials. On the combination.

# %% [markdown]
# # Day 2 : First program.

# %%
print("Hello World")

# %%
print(8*8)

# %%
print("Bye")

# %%
print("*Wanderer of Dreams* \nIn the quiet hush of twilight’s gleam, \nWhen stars begin their nightly theme,\nA wanderer walks with steps so light, \nThrough the tapestry of the coming night. \n \nHe carries dreams within his eyes, \nMirrored from the endless skies, \nWhispers of the wind he hears, \nAs the world dissolves its fears.")

# %%
def square(n):
    return n*n

# this program has O(1) as the operation is one and is going to stay that way irrespective of the input number n.

# %%
print(square(88888))

# %%
def print_items(n):
    for i in range(n+1):
        print("Hello World", i)
        
        
print_items(10)

# this program has time complexity of O(n) as it performs n operation depending on input n.
# previous square program was performing only 1 operation single irrespective of numbers input n.
# This program will have different space complexity as well further discussed 
# when learned find the space complecity of this one.

# %%
# droping constant in Big O.
def print_twice(n):
    for i in range(n):
        print(i)
    for j in range(n):
        print(j)

print_twice(10)

# actual time Complexity of the program is O(N + N) => O(2N) as the operation is done n times and twice.
# but we drop the constant to get the approximate time complexity as O(N)
# In practical examples the constant represents the hardware or the computer. we are not looking for faster/ slower computr
# we are intersted in the algorithms as constant represnts the computer, we elimate the constants to get algo info.
# As N approaches Infinity, constant factors are not a big deal.

# %%
def print_nested(n):
    for i in range(n):
        for j in range(n):
            print((i,j))

print_nested(2)

# %% [markdown]
# ## Quadratic Time COmplexity O(N^2)
# - When passed 2 it is performing 4 operation.
# - passed 10 performed 100 operation so its like it perfomring the n square operation for every n.
# - previously when passed n it was performing twice n opersation now its squaring the number of operation depend on the input provided.
# - Time Complexity for this Loop is O(N^2).

# %%
def pair_sum_sequence(n):
    total = 0
    for i in range(n):
        total = total + pair_sum(i, i+1)
    return total

def pair_sum(a,b):
    return a + b

pair_sum_sequence(3)

# %% [markdown]
# ## About Space compelexity of above program.
# - the call stack will remove the pair_sum function from stack simultaneously when it exits the pair_sum and goes to next pair_sum_sequence.
# - O(1)

# %%
def print_items(a,b):
    for i in range(a):
        print(i)
    for j in range(b):
        print(j) 

# for this type of problem time complexity will be O(a + b)

# %% [markdown]
# ## Time Complexity when to add and when to multiply.
#
# - If Algorithms is in the form of "do this, then when all done, do that" then you **add** the runtimes.
# - If Algorithm is in the form of "do this for each time you do that", then you **Multiply** the runtimes.

# %% [markdown]
# ## Time Comlexity measure for the code.
#
# 1. Rule no 1 : any asignment statemnts and if statemnts that executed once *regardless of the size* of the problem is **counted as O(1).**
# 2. Rule 2 : *Simple For loop* from 0 to N (with no internal loops) is **measured as O(N).**
# 3. rule 3 : a *nexted loop* for the same type takes quadratic time complexity **O(N^2).**
# 4. rule 4: a loop in which the *controlling parameter is divided* by two each step take logarithmic Time complexity,**O(log N)**
# 5. When dealing with multiple statemntss.,just add them up.
#
# > method to actually step by step measure time complexity
# [Link](https://www.udemy.com/course/data-structures-and-algorithms-bootcamp-in-python/learn/lecture/17316742#notes)

# %% [markdown]
# # Day 3 Array
# ### Twitter

# %%
import array

my_array = array.array('i')
my_array1 = array.array('i', [1,2,3,4])
print(my_array)

# %%
print(my_array1)

# %%
import numpy as np
np_array = np.array([], dtype=int)
print(np_array)

# %%
np_array1 = np.array([1,2,3,4])
print(np_array1)

# %% [markdown]
# ## Inserting into an Array with Array Module

# %%
import array
my_array1 = array.array('i', [1,2,3,4])
my_array1.insert(4,6)
print(my_array1)

# %% [markdown]
# ## Array Traversal

# %%
import array
arr1 = array.array('i', [1,2,3,4,5,4,7])

def traverseArray(array):
    for i in array:
        print(i)

traverseArray(arr1)

# O(N) + O(1)

# %% [markdown]
# ## Accessing Element

# %%
import array
arr1 = array.array('i', [1,2,3,4,5,4,7])

def accessElement(array, index):
    if(index >= len(array)):
        print("out of bound index entered.")
    else:
        print(array[index])
        
print("!!!!!!!!!!!!! GOT THE OUTPUT !!!!!!!!!!!!")
accessElement(arr1, 3)

# %% [markdown]
# ### Searching Element in array

# %%
import array
arr1 = array.array('i', [1,2,3,4,5,4,7])

def linear_search(array, target):
    for i in range(len(arr1)): # O(N)
        if arr1[i] == target: # O(1)
            return i # O(1)
    return -1 # O(1)

print(linear_search(arr1, 3)) # O(1)

""""
total complexity for the program is O(N) + O(1) + O(1) + O(1) + O(1)
total is O(N)
""""

# %% [markdown]
# ### Deleting Element in array

# %%
import array
arr2 = array.array('i', [1,2,3,4,5,6])

arr2.remove(3)

print(arr2)

arr2.insert(5,2)

print(arr2)

# %% [markdown]
# #### Practice 16 different operatiions on Array

# %%
# 1:  create an array and traverse through it

import array

new_arr = array.array('i',[1,2,3,4,5,6,7])

def traverse_array(array):
    for i in range(len(new_arr)):
        print(new_arr[i])
        
# time complexity O(N) Program.

traverse_array(new_arr)

# %%
# 2:  accessing first element

import array

new_arr = array.array('i',[1,2,3,4,5,6,7])

print("printing First Element")
print(new_arr[0])

# %%
# 3: inserting element using append method.

import array

new_arr = array.array('i',[1,2,3,4,5,6,7])

new_arr.append(8)

print(new_arr)

# %%
# 4: Inserting element using insert(#,#) this is time consuoimg


new_arr.insert(8, 9)
print(new_arr)

# time consuming process as the array make a right shift always.

# %%
# 5: array extending using extend method. to new array
import array

new_arr = array.array('i',[1,2,3,4,5,6,7])

my_array1 = array.array('i', [20, 30 , 40])
new_arr.extend(my_array1)
print(new_arr)

# %%
# 6: Adding  elements to array from List.

my_list = [10, 20, 30]
print("my_list = ", my_list)
new_arr.fromlist(my_list)
print(new_arr)

# %%
# 7: removing element using remove() method

new_arr.remove(20)
print(new_arr)

# %%
# removing using pop() method

new_arr.pop()
print(new_arr)
print(len(new_arr))

# %%
# 9: fetch any element using its Index method

new_arr.index(30)
new_arr.index(7)

# %%
# 10: reverse an array using reverse() method

new_arr.reverse()
print(new_arr)

# %%
# 11: buffer info about array using buffer_info() method

print(new_arr.buffer_info())

# %%
# 12: check for occurence using Count() method

print(new_arr.count(40))

# %%
# 13: convert array to string array

temp_arr = array.array('i', [50,60,70,80])
strArray = temp_arr.tostring()
print(strArra)

# %%
# 14: convert array  to python list with some elements using tolist() method.
print(new_arr.tolist())

# %%
# 15: append string to char using fromstring() method

# %%
# 16: slice elements in array
print(new_arr[0:8])
print(new_arr[:5])
print(new_arr[6:])
print(new_arr[0:])

# %% [markdown]
# ### TWO D ARRAY

# %%
# SKIPPED STEP 34 TO 41 FOR 2D ARRAY

# %% [markdown]
# ### wHEN TO USE ARRAY

# %% [markdown]
# > Pros
# - TO store muultiple variables of the same data types/
# - random access/
# - effiecient in terms of time complexity.
#
# > limitations
# - same data types/
# - reserves specific amount of memory even if the element is not added.

# %% [markdown]
# # Day 4 Python List
#
# ###### 28 aug.

# %% [markdown]
# ### Goal:  Python Lists
# #### elements can be mix of [ integer, string, float, list[] ]
# #### nested lists advance level.

# %%
# list of integers.

integers = [1, 2,3,4,5]
print(integers)

# %%
string_list = ['str_list', 'hello', 'world']
print(string_list)

# %%
mix_list = [1,2,3,'stringValue',1.2]
print(mix_list)

# %%
nested_list = [1.2, 3, 'stringValue',[2,3,4]]
print(nested_list)

# %% [markdown]
# #### Accessing List

# %%
shoppingList = ['cheese' , 'butter' , 'milk']

print(shoppingList[0])
print(shoppingList[2])

def print_element(array, index):
    if index >= len(array):  # Corrected the condition
        print('please enter a valid index')
    else:
        print(array[index])


def traverse_list(list):
    for i in range(len(list)):
        print(list[i])
        
print_element(shoppingList, 1)
traverse_list(shoppingList)

# %% [markdown]
# #### Inserting / appending in list

# %%
myList = [1,2,3,4,5]
print(myList)

# %%
# insert in list
myList.insert(4,14)
print(myList)

# %%
# append
myList.append(55)
print(myList)

# %%
# extend method
new_list=[11,12,13,14]
myList.extend(new_list)
print(myList)

# %%
# delete
del myList[1:2]
myList.pop(1)

print(myList)

# %%
def linear_search(p_list, p_target):
    for i, value in enumerate(p_list):
        if value == p_target:
            return i
        return -1
    
print(linear_search(myList, 0))

# %%
a = [1,2,3]
b = [4,5,6]
c = a + b
print(c)
c = c * 4

print(c)

# %%
print(min(c))

# %%
print(max(c))

# %%
print(sum(c))

# %%
# String to List


a = 'spam1-span2-span3'
delimiter = '-'
b = a.split(delimiter)
print(b)
print(b[1])

print('\n')
print('List to the String')
# list to the string
print(delimiter.join(b))

# %% [markdown]
# # Day 5
# ##### 29 aug.

# %%
my_new_list = [2,3,4,5,6]

my_list5 = [2,5,6,6]
orig = my_list5[:]

print(orig)
print('\n')
my_list5.append([3])

print(my_list5)

# %% [markdown]
# #### List vs Array

# %%
import numpy as np

myArray = np.array([2,3,4,5,6])
my_list6 = [1,2,3,4,5]

print(myArray/2)

# %%
@TIME COMPEXITY

# %%
prev_list = [1,2,3]
new_list = []

for i in prev_list:
    multiply_2 = i *2
    new_list.append(multiply_2)
    
print(new_list)

# %% [markdown]
# ### List Comprehension

# %%
# new_list = [new_item for item in list]

new_list = [i*2 for i in prev_list]
print(new_list)

# %%
prev_list = [-1, 10, -20, 30, 4, -3, 54, -33]
positive_list = [number if number > 0 else 0 for number in prev_list]
print(positive_list)

# %%
 # So what Vercel CEO was saying...
    """
    In future all That Development Part is
    Going to be done by AI + Engineers.
    So main Focus as me being Softeare Engineer
    is Develop Coding Skills.
    
    Whenever You focus on MacBook, just focus on Coding,
    
    Here is new Game you.
    
    New Algorithm -
    1. Early Morning 
    04am : Leetcode atleast 1 Problem.
    05am : Squats, Push, Pull.
    06am : Nutrition ( Prepare 5 Meals for you.)
    07am : 100daysofcode.
    08am : Shower Hot / Cold.
    
    09am : Connect with Higher Consiousness 10min
    10am : Communication.
    11am : Communication.
    12pm : Focus while Being Speaking to ma'am
    01pm : 
    02pm :
    03pm :
    04pm :
    05pm : LEETCODE.
    06pm : Push. Pull. Squats.
    07pm : 
    08pm :
    09pm :
    10pm :
    
    
    
    """

# %% [markdown]
# # New Algorithm Effective from 31st Aug.
#
# | Ticking   | Activity   |
# |-------------|-------------|
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |
# | 00am  | Leetcode  |

# %%
"""
The problems you face today is misunderstanding of you and consciousness. Consciousness over the decades and centuries have changed to something called Money $$$. 
Today you notice everything is money where in Back-end  in 500 Years Back-end we had Buddha who had said that Consciousness is the mind. But what if the Money plays role of Mind itself. If money is playing the mind Game then everything had become easy.

When I say Consciousness Ambedkar, he only said the The problem of Rupee. The biggest boddhisttva has himself seen Money Problem as conscious Problem itself.

I fully confident of that is Money is Future Consciousness. People will always need Consciousness that why separates it from Animals. Human have higher consciousness.

It is rule of Nature for centuries and since the First organism was born is to follow highest Consciousness.

Consciousness Creates reality. The more conious you have the higher consciousness you have, you have the command over the World.

So whatever I spend in a day has to be made with copiousness.

Below is the activity and how much copiousness I can attain with it.

There is no way possible, I look that miserable right now. I need to calm lil bit down.
You are literally doing the most but a single thing which you keep going is not having a mindset upto this day.

What ever inside mind 😑 
What ever future hold 🌱


"""

# %% [markdown]
# | Activity/hrs/place  | Consiousness ? |
# |-------------|-------------|
# | Twitter 2hrs  | 0  |
# | Course Udemy  | 0  |
# | CDAC  | 0  |
# | Exercise  | 0  |

# %%
# Without using Array

numDays = int(input("How many day's of Temperature ?")) #O(1)
total = 0 #O(1)
for i in range(1, numDays +1): O(N)
    nextDay = int(input("Day" + str(i) + "'s high temp:'"))
    total += nextDay

avg = round(total/numDays,2)
print("\nAverage = " + str(avg))

# Time Complexity for the program is O(N)

# %%
numDays = int(input("How many day's of Temperature ?")) #O(1)
total = 0 #O(1)
temp = []
for i in range(numDays): #O(N)
    nextDay = int(input("Day " + str(i+1) + "s high temp"))
    temp.append(nextDay)
    total += temp[i]

avg = round(total/numDays,2)
print("\nAverage = " + str(avg))

above_Temp = 0
for i in temp:
    if i > avg:
        above_Temp += 1
print(str(above_Temp) + " Day(s) is/are above average Temperature.")

# Time Complexity for the program is O(N)

# %% [markdown]
# # Total 9 FAANG PROBLEMS

# %%
def missing_number(arr, n):
    # TODO
    sum_natural = n * (n + 1) // 2
    actual_sum = sum(arr)
    
    missing_number = sum_natural - actual_sum
    
    return missing_number
    
        
        
        
        
        
        
        
        
        
    
    """
    
    brute force approach
    arr = [1,2,3,4,5,6,8,9]
    perfect_list = [1,2,3,4,5,6,7,8,9]
    miss_num = array.array('i',[])
    
    
    for i in range(0,n):
            if(arr[i] != perfect_array[i]):
                miss_num.extend(perfect_array[i]):
    
    other Approach :
    sum - actual_sum = missing number.
                
                
            
    
    unknown_missing_value = -1
    
        
    """

# %% [markdown]
# ## FAANG Big 0 interview Questions.

# %%
# Fund runtime of the code 

def foo(array): #1
    sum = 0 # 1
    product = 1 # 1
    for i in array: # N
        sum+=i # 1
    for i in array: # N
        product += i # 1
    print("Sum = "+str(sum)+", Product = "+ str(product())) # 1

    """
    total = 1 + 1 + 1 + n + n + 1+ 1.
    By Rules,
    O(5(1)) + O(2N)
    eliminating constants and low dominating terms.
    we get,
    
    Runtime :
    O(N)
    """

# %%
# Q 2 

def printPairs(array): # 1
    for i in array: # O(N^2) CAUSE FOR EACH BELOW LOOP THIS LOOP IS RUNNING.
        for j in array: #O(N)
            print(str(i)+","+str(j)) # 1
        
"""
By Rules, 
eliminating constants and low dominating terms,
and For each line 2, line 3 is happening.

O(N^2) + O(N).

O(N^2) Quadratic Complex.

"""

# %%
# Q 3

def printunorderedPairs(array): # 1
    for i in range(0,len(array)): # for every i + 1 this loop is running besides itself.
        # this loop is running @
        for j in range(i+1,len(array)): # 
            print("something here") # 1

"""
O(N^2)
"""

# %%
# 4 
def printunorderedPairs(arrayA, arrayB): # 1
    for i in range(len(arrayA)): # (N)
        for j in range(len(arrayB)): # (M)
            if(something here): #1
                print("something here")#1

'''
By Rules.
considering different length of arrays,
O(N) * O(M) , (FOR EACH THIS, THAT IS RUNNING)
'''

# %%
# 5
def printunorderedPairs(arrayA, arrayB):
    for i in range(len(arrayA)):
        for j in  range(len(arrayB)):
            for k in range(0,100000):
                print("something here");
                
'''
here the Run time is 
(N) * (N) * (10000)

final Answer is O(N^@)
'''

# %%
# 6

def reverse(array):
    for i in range(o, int(len(array)/2)): # n/2
        other = len(array)-i-1 # 1
        temp = array[i] # 1
        array[i] = array[other] # 1
        array[other] = temp # 1
    print(array) # 1
        
        '''
        O(n/2)
        
        O(N).
        '''

# %%
# 7
# MCQ
# 1 2 3 CORRECT
# WRONG 4 5

# %% [markdown]
# # Python Dictionary

# %%
# Printing Dict.

my_dict = dict()
print(my_dict)

# %%
eng_sp = dict(one='uno',two='dos',three='tres')
print(eng_sp)
pairs = {'one':'uno', 'two' :'dos','three' :'tres'}
pairs = {'one':'uno', 'two' :'dos','three' :'tres'}
print(pairs)

eng_sp_list = [('one','uno'),('two','dos'),('three','tres')]
eng_sp_list_to_dict = dict(eng_sp_list)
print(eng_sp_list_to_dict)

# %% [markdown]
# # Day 10:

# %%
myDict = {'Name': 'Edy', 'age' : 26, 'address':'London'}

# traverse in array.

def searchDict(dict, value):
    for key in dict:
        if dict[key] == value:
            return key, value
    return "The Value does not Exist"

print(searchDict(myDict, 26))

# %%
# DELETE element in array.

my_dict = {"Name": "Edy", "Age" : 26, "address":"CA"}
# removed_element = my_dict.pop("Name")
removed_pairs = my_dict.popitem()


print(removed_pairs)

print(my_dict)

# %%
myDict = {'Name': 'Edy','age':24,'address':'london' }

def searchDict(dict,value):
    for key in dict:
        if dict[key] == value:
            return key,value 
        
# Print / Search Method of the Dictionary.
        
    return 'The value does not Exist'

print(searchDict(myDict, 24))

# %%
del myDict['age']
print(myDict)

#Alt

# %%
removed_element = myDict.pop('nam', None)
# takes key and None as para.
print(removed_element)
print(myDict)

# %%
# TO CLEAR DICT
# myDict.clear()
copy_dict= myDict.copy()
print(copy_dict)

# %%
# fromkeys method.

newDict = {}.fromkeys([1,2,3],0)

print(newDict)

# %%
# get method to search key, value and third None

print(myDict.get('name',22))

# %%
# items method return all key value pairs.

print(myDict.items())

# %%
# keys method returns all keys

print(myDict.keys())

# %%
# popitem take no value
# pop('1',None) > take two para as key and None.

print(myDict.popitem())

# %%
# SEARCH METHOD by key value pair.

print(myDict.setdefault('Key_NAME'))

# %%
# update method adds one dict to other dict.
